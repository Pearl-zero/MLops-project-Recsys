# %%
import numpy as np
import pandas as pd
import pickle
from surprise import Reader, Dataset
from sklearn.linear_model import Ridge
import json

# %%
df_merged = pd.read_csv('../data/merged_movies.csv', encoding='utf-8')
df_ratings = pd.read_csv("../data/ratings.csv")
df_ratings = df_ratings.groupby('movieId').filter(lambda x: len(x) > 10).groupby('userId').filter(lambda x: len(x) > 5)

reader = Reader()
data = Dataset.load_from_df(df_ratings[['userId', 'movieId', 'rating']], reader)
trainset = data.build_full_trainset()

# %%
# Load the SVD model from the saved file
with open('svd_model.pkl', 'rb') as f:
    svd = pickle.load(f)

    new_user_id = df_ratings['userId'].max() + 1  # Assign an ID to the new user
    
    # Select random movie IDs from actual movie IDs in df_ratings
    movie_ids = df_ratings['movieId'].unique()
    random_movie_ids = np.random.choice(movie_ids, size=10, replace=False)
    
    # Generate random user ratings for these movies
    new_user_ratings = {int(movie_id): np.random.randint(1, 6) for movie_id in random_movie_ids}
    
    # Step 1: Map raw IDs to inner IDs and collect item factors and biases
    item_inner_ids = {}
    qi_list = []
    bi_list = []
    ratings_list = []
    
    for raw_iid, rating in new_user_ratings.items():
        try:
            inner_id = trainset.to_inner_iid(raw_iid)
            item_inner_ids[raw_iid] = inner_id
            qi = svd.qi[inner_id]  # Item factors
            bi = svd.bi[inner_id]  # Item bias
            qi_list.append(qi)
            bi_list.append(bi)
            ratings_list.append(rating)
        except ValueError:
            # The item was not in the training set
            print(f"MovieId {raw_iid} not in training set, skipping.")
    
    # Step 2: Set up the least squares problem to solve for pu and bu
    ratings_arr = np.array(ratings_list)
    global_mean = trainset.global_mean
    bi_arr = np.array(bi_list)
    y = ratings_arr - global_mean - bi_arr  # Target variable
    
    qi_arr = np.array(qi_list)  # Design matrix without bias term
    X = np.hstack([np.ones((qi_arr.shape[0], 1)), qi_arr])  # Add bias term
    
    # Solve for theta = [bu, pu]
    # theta, residuals, rank, s = np.linalg.lstsq(X, y, rcond=None)
    # bu = theta[0]
    # pu = theta[1:]
    # use Ridge regression instead of `np.linalg.lstsq` for efficiency
    ridge = Ridge(alpha=1.0)
    ridge.fit(X, y)
    theta = ridge.coef_
    bu = theta[0]
    pu = theta[1:]
    
    # Step 3: Predict ratings for all items
    # Get all item factors and biases
    qi_all = svd.qi
    bi_all = svd.bi
    
    # Compute predicted ratings
    r_hat = global_mean + bu + bi_all + qi_all.dot(pu)
    
    # Map inner IDs to raw IDs
    inner_ids = np.arange(trainset.n_items)
    raw_ids = [int(trainset.to_raw_iid(inner_id)) for inner_id in inner_ids]

    min_length = min(len(raw_ids), len(r_hat))
    raw_ids = raw_ids[:min_length]
    r_hat = r_hat[:min_length]

    # Ensure lengths are consistent
    if len(raw_ids) != len(r_hat):
        print(f"Mismatch: raw_ids length = {len(raw_ids)}, r_hat length = {len(r_hat)}")
        # Align lengths here if necessary or investigate why they differ
        exit()
    
    # Create a DataFrame with predictions
    predictions_df = pd.DataFrame({
        'movieId': raw_ids,
        'est_rating': r_hat
    })
    
    # Remove movies the user has already rated
    rated_movie_ids = set(new_user_ratings.keys())
    predictions_df = predictions_df[~predictions_df['movieId'].isin(rated_movie_ids)]
    
    # Step 4: Get top 10 recommendations
    top_recommendations = predictions_df.sort_values('est_rating', ascending=False).head(10)
    
    # print(f"Top 10 recommendations for new user:")
    # print(top_recommendations[['movieId', 'est_rating']])

    top_recommendation_details = pd.merge(
        top_recommendations, 
        df_merged, 
        left_on='movieId', 
        right_on='id'
    )
    
    # Select only relevant columns for the JSON response
    top_recommendation_details = top_recommendation_details[['movieId', 'imdb_id', 'tmdb_id', 'title', 'release_date', 'genres', 'cast', 'crew', 'keywords', 'est_rating']]
    
    # Convert to dictionary format (or JSON-like structure)
    json_response = top_recommendation_details.to_dict(orient='records')
    
    # Print or return the JSON response
    print(json.dumps(json_response, indent=4))  # Pretty print the JSON
# Out:
# [
#     {
#         "movieId": 4369,
#         "imdb_id": 231844,
#         "tmdb_id": 4369,
#         "title": "Just a Question of Love",
#         "release_date": "2000-01-01",
#         "genres": "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]",
#         "cast": "[{'cast_id': 5, 'character': 'Laurent', 'credit_id': '52fe43bdc3a36847f806bd69', 'gender': 0, 'id': 38449, 'name': 'Cyrille Thouvenin', 'order': 0, 'profile_path': '/lJXcAuLhjL1LuFeCkpIEryplyvD.jpg'}, {'cast_id': 6, 'character': 'C\u00e9dric', 'credit_id': '52fe43bdc3a36847f806bd6d', 'gender': 2, 'id': 38450, 'name': 'St\u00e9phan Gu\u00e9rin-Tilli\u00e9', 'order': 1, 'profile_path': '/AdFNoHxVeVMRzVI612oNuhHOLnx.jpg'}, {'cast_id': 7, 'character': 'Carole', 'credit_id': '52fe43bdc3a36847f806bd71', 'gender': 0, 'id': 38451, 'name': 'Caroline Veyt', 'order': 2, 'profile_path': None}, {'cast_id': 8, 'character': 'Emma', 'credit_id': '52fe43bdc3a36847f806bd75', 'gender': 1, 'id': 25346, 'name': 'Eva Darlan', 'order': 3, 'profile_path': '/vMVsYB9ZQS2r2QOZ4smkMbjSUuD.jpg'}, {'cast_id': 9, 'character': 'Jeanne', 'credit_id': '52fe43bdc3a36847f806bd79', 'gender': 0, 'id': 38452, 'name': 'Dani\u00e8le Denie', 'order': 4, 'profile_path': '/vSI8ZLNQAL1nCzYNhems1CPljhf.jpg'}, {'cast_id': 10, 'character': 'Pierre', 'credit_id': '52fe43bdc3a36847f806bd7d', 'gender': 0, 'id': 38453, 'name': 'Idwig Stephane', 'order': 5, 'profile_path': None}]",
#         "crew": "[{'credit_id': '52fe43bdc3a36847f806bd53', 'department': 'Directing', 'gender': 2, 'id': 38446, 'job': 'Director', 'name': 'Christian Faure', 'profile_path': None}, {'credit_id': '52fe43bdc3a36847f806bd59', 'department': 'Writing', 'gender': 2, 'id': 38446, 'job': 'Author', 'name': 'Christian Faure', 'profile_path': None}, {'credit_id': '52fe43bdc3a36847f806bd5f', 'department': 'Writing', 'gender': 0, 'id': 38447, 'job': 'Author', 'name': 'Annick Larboulette', 'profile_path': None}, {'credit_id': '52fe43bdc3a36847f806bd65', 'department': 'Writing', 'gender': 0, 'id': 38448, 'job': 'Author', 'name': 'Pierre Pauquet', 'profile_path': None}, {'credit_id': '52fe43bdc3a36847f806bd83', 'department': 'Camera', 'gender': 0, 'id': 41665, 'job': 'Director of Photography', 'name': 'Louis-Philippe Capelle', 'profile_path': None}, {'credit_id': '52fe43bdc3a36847f806bd89', 'department': 'Sound', 'gender': 0, 'id': 41666, 'job': 'Original Music Composer', 'name': 'Charles Court', 'profile_path': None}, {'credit_id': '52fe43bdc3a36847f806bd8f', 'department': 'Editing', 'gender': 0, 'id': 41667, 'job': 'Editor', 'name': 'Marie-Claude Lacambre', 'profile_path': None}, {'credit_id': '52fe43bdc3a36847f806bd95', 'department': 'Art', 'gender': 0, 'id': 41668, 'job': 'Production Design', 'name': 'Perrine Rulens', 'profile_path': None}, {'credit_id': '52fe43bdc3a36847f806bd9b', 'department': 'Costume & Make-Up', 'gender': 0, 'id': 41669, 'job': 'Costume Design', 'name': 'Christine Jacquin', 'profile_path': None}]",
#         "keywords": "[{'id': 237, 'name': 'gay'}, {'id': 699, 'name': 'love at first sight'}, {'id': 725, 'name': 'lovesickness'}, {'id': 1013, 'name': 'homophobia'}, {'id': 1605, 'name': 'new love'}, {'id': 1862, 'name': 'coming out'}, {'id': 2038, 'name': \"love of one's life\"}, {'id': 4320, 'name': 'lover'}, {'id': 4663, 'name': 'lovers'}, {'id': 5091, 'name': 'kiss'}, {'id': 5608, 'name': 'affection'}, {'id': 6056, 'name': 'tenderness'}, {'id': 6170, 'name': 'motherly love'}, {'id': 6281, 'name': 'partnership'}, {'id': 7879, 'name': 'secret love'}, {'id': 10180, 'name': 'homosexuality'}, {'id': 10791, 'name': 'teenage crush'}, {'id': 158718, 'name': 'lgbt'}]",
#         "est_rating": 4.926662027009379
#     },
#     {
#         "movieId": 1917,
#         "imdb_id": 326036,
#         "tmdb_id": 1917,
#         "title": "Who Killed Bambi?",
#         "release_date": "2003-12-24",
#         "genres": "[{'id': 53, 'name': 'Thriller'}]",
#         "cast": "[{'cast_id': 9, 'character': 'Isabelle', 'credit_id': '52fe4321c3a36847f803ca37', 'gender': 1, 'id': 19933, 'name': 'Sophie Quinton', 'order': 0, 'profile_path': '/rccsEw7wSD75ZDTZeIqTSIj2rew.jpg'}, {'cast_id': 10, 'character': 'Dr. Philipp', 'credit_id': '52fe4321c3a36847f803ca3b', 'gender': 2, 'id': 18178, 'name': 'Laurent Lucas', 'order': 1, 'profile_path': '/aS3qVgThNSuRQfThOs9e1Y0YSjz.jpg'}, {'cast_id': 11, 'character': 'V\u00e9ronique', 'credit_id': '52fe4321c3a36847f803ca3f', 'gender': 1, 'id': 19934, 'name': 'Catherine Jacob', 'order': 2, 'profile_path': '/8oIJONHTme3pZYq243vEL295MLG.jpg'}, {'cast_id': 12, 'character': 'Sami', 'credit_id': '52fe4321c3a36847f803ca43', 'gender': 1, 'id': 19935, 'name': 'Yasmine Belmadi', 'order': 3, 'profile_path': None}, {'cast_id': 13, 'character': 'Mme Vachon', 'credit_id': '52fe4321c3a36847f803ca47', 'gender': 1, 'id': 19936, 'name': 'Mich\u00e8le Moretti', 'order': 4, 'profile_path': '/8Nw5bRGpITncsuryF6oYLD8sGHs.jpg'}, {'cast_id': 14, 'character': 'Nathalie', 'credit_id': '52fe4321c3a36847f803ca4b', 'gender': 1, 'id': 19937, 'name': 'Val\u00e9rie Donzelli', 'order': 5, 'profile_path': '/gb6XyP4OsRz3LMf8ljWJfdekUvh.jpg'}, {'cast_id': 15, 'character': 'Carole', 'credit_id': '52fe4321c3a36847f803ca4f', 'gender': 0, 'id': 19938, 'name': 'Sophie Medina', 'order': 6, 'profile_path': '/aQSz7EmryJiLYNjdA3hmbPNr2Ar.jpg'}]",
#         "crew": "[{'credit_id': '52fe4321c3a36847f803ca2d', 'department': 'Editing', 'gender': 2, 'id': 17387, 'job': 'Editor', 'name': 'Robin Campillo', 'profile_path': None}, {'credit_id': '52fe4321c3a36847f803ca27', 'department': 'Camera', 'gender': 0, 'id': 17393, 'job': 'Director of Photography', 'name': 'Pierre Milon', 'profile_path': None}, {'credit_id': '52fe4321c3a36847f803ca1b', 'department': 'Production', 'gender': 0, 'id': 17424, 'job': 'Producer', 'name': 'Carole Scotta', 'profile_path': None}, {'credit_id': '52fe4321c3a36847f803ca15', 'department': 'Writing', 'gender': 2, 'id': 18176, 'job': 'Screenplay', 'name': 'Gilles Marchand', 'profile_path': None}, {'credit_id': '52fe4321c3a36847f803ca09', 'department': 'Directing', 'gender': 2, 'id': 18176, 'job': 'Director', 'name': 'Gilles Marchand', 'profile_path': None}, {'credit_id': '52fe4321c3a36847f803ca0f', 'department': 'Writing', 'gender': 0, 'id': 19930, 'job': 'Screenplay', 'name': 'Vincent Dietschy', 'profile_path': '/wWCAZyFIN77rR6ofs3NYyKU0i4d.jpg'}, {'credit_id': '52fe4321c3a36847f803ca21', 'department': 'Production', 'gender': 1, 'id': 19931, 'job': 'Producer', 'name': 'Caroline Benjo', 'profile_path': None}, {'credit_id': '52fe4321c3a36847f803ca33', 'department': 'Art', 'gender': 0, 'id': 19932, 'job': 'Production Design', 'name': 'Laurent Deroo', 'profile_path': None}]",
#         "keywords": "[{'id': 428, 'name': 'nurse'}, {'id': 2619, 'name': 'suspicion of murder'}, {'id': 3262, 'name': 'surgeon'}, {'id': 11612, 'name': 'hospital'}, {'id': 15127, 'name': 'killer'}]",
#         "est_rating": 4.811246918529148
#     },
#     {
#         "movieId": 2861,
#         "imdb_id": 82053,
#         "tmdb_id": 2861,
#         "title": "A Good Marriage",
#         "release_date": "1982-05-19",
#         "genres": "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]",
#         "cast": "[{'cast_id': 4, 'character': 'Sabine', 'credit_id': '52fe4371c3a36847f8054a51', 'gender': 1, 'id': 28611, 'name': 'B\u00e9atrice Romand', 'order': 0, 'profile_path': '/44XNrVHZWwgoCWDdWGM7Km5Tjkh.jpg'}, {'cast_id': 5, 'character': 'Edmond', 'credit_id': '52fe4371c3a36847f8054a55', 'gender': 2, 'id': 18177, 'name': 'Andr\u00e9 Dussollier', 'order': 1, 'profile_path': '/rKZXoZJBUMKRbACbAGEat7wvAr7.jpg'}, {'cast_id': 6, 'character': 'Simon', 'credit_id': '52fe4371c3a36847f8054a59', 'gender': 2, 'id': 20285, 'name': 'F\u00e9odor Atkine', 'order': 2, 'profile_path': '/cf50q5tFxLlp6rlSyG96AlhZrfi.jpg'}, {'cast_id': 7, 'character': 'Clarisse', 'credit_id': '52fe4371c3a36847f8054a5d', 'gender': 1, 'id': 28626, 'name': 'Arielle Dombasle', 'order': 3, 'profile_path': '/yl6RniErLOkQKxUJjn791WBJB5O.jpg'}, {'cast_id': 8, 'character': 'Lise', 'credit_id': '52fe4371c3a36847f8054a61', 'gender': 0, 'id': 28627, 'name': 'Sophie Renoir', 'order': 4, 'profile_path': '/yBHb9FBR2kgTY32IxPCph1sjeaJ.jpg'}, {'cast_id': 9, 'character': 'Nicolas', 'credit_id': '52fe4371c3a36847f8054a65', 'gender': 2, 'id': 16923, 'name': 'Pascal Greggory', 'order': 5, 'profile_path': '/1J3QISHIZg6C1xkhvshtX2lEiDG.jpg'}, {'cast_id': 14, 'character': 'Maryse, Antique Dealer', 'credit_id': '59cb4058c3a368776e00a99b', 'gender': 0, 'id': 1524414, 'name': 'Huguette Faget', 'order': 6, 'profile_path': None}, {'cast_id': 15, 'character': 'Mother of Sabine', 'credit_id': '59cb405e9251412bb300a1a1', 'gender': 0, 'id': 1895450, 'name': 'Thamila Mezbah', 'order': 7, 'profile_path': None}, {'cast_id': 16, 'character': 'Fr\u00e9d\u00e9ric', 'credit_id': '59cb4069c3a368770e009881', 'gender': 0, 'id': 543843, 'name': 'Herv\u00e9 Duhamel', 'order': 8, 'profile_path': None}, {'cast_id': 17, 'character': 'The Bride', 'credit_id': '59cb406f9251412be1009c8a', 'gender': 1, 'id': 18484, 'name': 'Virginie Th\u00e9venet', 'order': 9, 'profile_path': '/tAxOXN4exUN0cIR0hLwsXPUIbNX.jpg'}, {'cast_id': 18, 'character': 'Comtesse', 'credit_id': '59cb40759251412bb300a1bb', 'gender': 0, 'id': 1895451, 'name': 'Denise Bailly', 'order': 10, 'profile_path': None}, {'cast_id': 19, 'character': 'Claude', 'credit_id': '59cb407bc3a368779700af7c', 'gender': 0, 'id': 47226, 'name': 'Vincent Gauthier', 'order': 11, 'profile_path': None}, {'cast_id': 20, 'character': 'La secr\u00e9taire', 'credit_id': '59cb40849251412bd900a2ee', 'gender': 0, 'id': 1833948, 'name': 'Anne Mercier', 'order': 12, 'profile_path': None}, {'cast_id': 21, 'character': 'Cliente', 'credit_id': '59cb408a9251412b9800a636', 'gender': 0, 'id': 1895452, 'name': 'Catherine Rethi', 'order': 13, 'profile_path': None}]",
#         "crew": "[{'credit_id': '59cb4042c3a368776e00a97f', 'department': 'Editing', 'gender': 1, 'id': 3838, 'job': 'Editor', 'name': 'C\u00e9cile Decugis', 'profile_path': None}, {'credit_id': '59cb40239251412bb300a156', 'department': 'Production', 'gender': 1, 'id': 6100, 'job': 'Producer', 'name': 'Margaret M\u00e9n\u00e9goz', 'profile_path': None}, {'credit_id': '52fe4371c3a36847f8054a4d', 'department': 'Camera', 'gender': 0, 'id': 24846, 'job': 'Director of Photography', 'name': 'Bernard Lutic', 'profile_path': None}, {'credit_id': '52fe4371c3a36847f8054a41', 'department': 'Directing', 'gender': 2, 'id': 28615, 'job': 'Director', 'name': '\u00c9ric Rohmer', 'profile_path': '/4VUnQk2yA6m58uak9LguIAzZ8Re.jpg'}, {'credit_id': '52fe4371c3a36847f8054a47', 'department': 'Writing', 'gender': 2, 'id': 28615, 'job': 'Author', 'name': '\u00c9ric Rohmer', 'profile_path': '/4VUnQk2yA6m58uak9LguIAzZ8Re.jpg'}, {'credit_id': '59cb402a9251412b8f00a819', 'department': 'Sound', 'gender': 0, 'id': 1435057, 'job': 'Original Music Composer', 'name': 'Ronan Girre', 'profile_path': None}, {'credit_id': '59cb40329251412bcd00a23a', 'department': 'Sound', 'gender': 0, 'id': 1895449, 'job': 'Original Music Composer', 'name': 'Simon des Innocents', 'profile_path': None}]",
#         "keywords": "[]",
#         "est_rating": 4.791066476354067
#     },
#     {
#         "movieId": 1726,
#         "imdb_id": 371746,
#         "tmdb_id": 1726,
#         "title": "Iron Man",
#         "release_date": "2008-04-30",
#         "genres": "[{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 12, 'name': 'Adventure'}]",
#         "cast": "[{'cast_id': 19, 'character': 'Tony Stark / Iron Man', 'credit_id': '52fe4311c3a36847f8037ee9', 'gender': 2, 'id': 3223, 'name': 'Robert Downey Jr.', 'order': 0, 'profile_path': '/1YjdSym1jTG7xjHSI0yGGWEsw5i.jpg'}, {'cast_id': 12, 'character': 'Lt. Col. James \"Rhodey\" Rhodes / War Machine', 'credit_id': '52fe4311c3a36847f8037ecb', 'gender': 2, 'id': 18288, 'name': 'Terrence Howard', 'order': 1, 'profile_path': '/MZeLxOH0PgL7xcvt865WVBvQDw.jpg'}, {'cast_id': 11, 'character': 'Obadiah Stane / Iron Monger', 'credit_id': '52fe4311c3a36847f8037ec7', 'gender': 2, 'id': 1229, 'name': 'Jeff Bridges', 'order': 2, 'profile_path': '/xms1RAY6q7Lzp7wNeRCB0kzhucn.jpg'}, {'cast_id': 9, 'character': 'Yinsen', 'credit_id': '52fe4311c3a36847f8037ebf', 'gender': 2, 'id': 17857, 'name': 'Shaun Toub', 'order': 3, 'profile_path': '/qRHZD8EdqeUor8A6tazJ3v3gxyD.jpg'}, {'cast_id': 10, 'character': 'Virginia \"Pepper\" Potts', 'credit_id': '52fe4311c3a36847f8037ec3', 'gender': 1, 'id': 12052, 'name': 'Gwyneth Paltrow', 'order': 4, 'profile_path': '/uSidH77gLyon3Zpg6y1GxpKJMdZ.jpg'}, {'cast_id': 18, 'character': 'Raza', 'credit_id': '52fe4311c3a36847f8037ee5', 'gender': 2, 'id': 57452, 'name': 'Faran Tahir', 'order': 5, 'profile_path': '/zEcur3BBkXD0gosZQ1nAZRyQZUq.jpg'}, {'cast_id': 24, 'character': 'J.A.R.V.I.S. (voice)', 'credit_id': '52fe4311c3a36847f8037efb', 'gender': 2, 'id': 6162, 'name': 'Paul Bettany', 'order': 6, 'profile_path': '/xN2pJ3DIPacYviSSwDovxizPS2w.jpg'}, {'cast_id': 17, 'character': 'Christine Everhart', 'credit_id': '52fe4311c3a36847f8037ee1', 'gender': 1, 'id': 57451, 'name': 'Leslie Bibb', 'order': 7, 'profile_path': '/vzm9Si3VzsZX0M4YxtQKgaojpOk.jpg'}, {'cast_id': 21, 'character': 'Agent Phil Coulson', 'credit_id': '52fe4311c3a36847f8037ef3', 'gender': 2, 'id': 9048, 'name': 'Clark Gregg', 'order': 8, 'profile_path': '/t8CLS2Zcy7IjcZkE1vtxl40h9rh.jpg'}, {'cast_id': 36, 'character': 'Award Ceremony Narrator (voice)', 'credit_id': '52fe4311c3a36847f8037f37', 'gender': 2, 'id': 163671, 'name': 'Will Lyman', 'order': 9, 'profile_path': '/xYU1FSeQhXLyg6VskqRBofFyoU8.jpg'}, {'cast_id': 25, 'character': 'Happy Hogan', 'credit_id': '52fe4311c3a36847f8037eff', 'gender': 2, 'id': 15277, 'name': 'Jon Favreau', 'order': 10, 'profile_path': '/sJSGJwGa3hjMlJNUCxF7wQwo7fb.jpg'}, {'cast_id': 28, 'character': 'Director Nick Fury', 'credit_id': '52fe4311c3a36847f8037f0b', 'gender': 2, 'id': 2231, 'name': 'Samuel L. Jackson', 'order': 11, 'profile_path': '/AvCReLikjzYEf9XjTQxbv3JWgKT.jpg'}, {'cast_id': 72, 'character': 'Stan Lee', 'credit_id': '52fe4311c3a36847f8037fc7', 'gender': 2, 'id': 7624, 'name': 'Stan Lee', 'order': 12, 'profile_path': '/dTr2gJPL7jELKVkcjtoNx80uVKR.jpg'}, {'cast_id': 37, 'character': 'Guard', 'credit_id': '52fe4311c3a36847f8037f3b', 'gender': 0, 'id': 78299, 'name': 'Tom Morello', 'order': 13, 'profile_path': '/7QQmzUqv8trWHBLKlDeeYYkZ4Gt.jpg'}, {'cast_id': 56, 'character': 'Jim Cramer', 'credit_id': '52fe4311c3a36847f8037f87', 'gender': 0, 'id': 203468, 'name': 'Jim Cramer', 'order': 14, 'profile_path': None}, {'cast_id': 23, 'character': 'Abu Bakaar', 'credit_id': '52fe4311c3a36847f8037ef7', 'gender': 2, 'id': 173810, 'name': 'Sayed Badreya', 'order': 16, 'profile_path': '/wMpSb8QfErr5a0NBKWc2a3Zxj47.jpg'}, {'cast_id': 29, 'character': 'General Gabriel', 'credit_id': '52fe4311c3a36847f8037f0f', 'gender': 2, 'id': 17200, 'name': 'Bill Smitrovich', 'order': 17, 'profile_path': '/rO5wJpx7ZlT6RaunZw20OGF6O2Y.jpg'}, {'cast_id': 26, 'character': 'William Ginter Riva', 'credit_id': '52fe4311c3a36847f8037f03', 'gender': 2, 'id': 12708, 'name': 'Peter Billingsley', 'order': 18, 'profile_path': '/2wlX6TzKnghrZHIdbtA2oKxKHcv.jpg'}, {'cast_id': 27, 'character': 'Major Allen', 'credit_id': '52fe4311c3a36847f8037f07', 'gender': 2, 'id': 40275, 'name': 'Tim Guinee', 'order': 19, 'profile_path': '/8UeJw5Nwfq6YUT6xGtyi184jmbd.jpg'}, {'cast_id': 38, 'character': 'Guard', 'credit_id': '52fe4311c3a36847f8037f3f', 'gender ...
#         "crew": "[{'credit_id': '52fe4311c3a36847f8037f21', 'department': 'Production', 'gender': 1, 'id': 7232, 'job': 'Casting', 'name': 'Sarah Finn', 'profile_path': None}, {'credit_id': '52fe4311c3a36847f8037ed1', 'department': 'Camera', 'gender': 2, 'id': 4867, 'job': 'Director of Photography', 'name': 'Matthew Libatique', 'profile_path': '/wUnEHGYRQRa459aGoTZpqYRwAIK.jpg'}, {'credit_id': '52fe4311c3a36847f8037f15', 'department': 'Production', 'gender': 2, 'id': 7624, 'job': 'Executive Producer', 'name': 'Stan Lee', 'profile_path': '/dTr2gJPL7jELKVkcjtoNx80uVKR.jpg'}, {'credit_id': '52fe4311c3a36847f8037ea9', 'department': 'Writing', 'gender': 2, 'id': 7624, 'job': 'Characters', 'name': 'Stan Lee', 'profile_path': '/dTr2gJPL7jELKVkcjtoNx80uVKR.jpg'}, {'credit_id': '52fe4311c3a36847f8037edd', 'department': 'Production', 'gender': 2, 'id': 7626, 'job': 'Producer', 'name': 'Avi Arad', 'profile_path': '/kIG4HF5LSywU0ZdDheDaEsxxohu.jpg'}, {'credit_id': '579489aac3a3687605001e64', 'department': 'Production', 'gender': 2, 'id': 10850, 'job': 'Producer', 'name': 'Kevin Feige', 'profile_path': '/AewbqQQT0FbcE358rcbopZ3zgDV.jpg'}, {'credit_id': '52fe4311c3a36847f8037f33', 'department': 'Costume & Make-Up', 'gender': 1, 'id': 9551, 'job': 'Costume Design', 'name': 'Laura Jean Shannon', 'profile_path': '/e7Cmmphpmw5SBwg5ypCY8zsI77o.jpg'}, {'credit_id': '52fe4311c3a36847f8037ed7', 'department': 'Editing', 'gender': 2, 'id': 11455, 'job': 'Editor', 'name': 'Dan Lebental', 'profile_path': None}, {'credit_id': '52fe4311c3a36847f8037eb5', 'department': 'Writing', 'gender': 2, 'id': 18866, 'job': 'Characters', 'name': 'Jack Kirby', 'profile_path': '/xLVSa7mX1BCyVoKD2wyRGEQXj8M.jpg'}, {'credit_id': '52fe4311c3a36847f8038059', 'department': 'Directing', 'gender': 2, 'id': 15277, 'job': 'Director', 'name': 'Jon Favreau', 'profile_path': '/sJSGJwGa3hjMlJNUCxF7wQwo7fb.jpg'}, {'credit_id': '52fe4311c3a36847f8037e9d', 'department': 'Writing', 'gender': 0, 'id': 18873, 'job': 'Screenplay', 'name': 'Art Marcum', 'profile_path': None}, {'credit_id': '52fe4311c3a36847f8037ea3', 'department': 'Writing', 'gender': 0, 'id': 18875, 'job': 'Screenplay', 'name': 'Matt Holloway', 'profile_path': None}, {'credit_id': '52fe4311c3a36847f8037eaf', 'department': 'Writing', 'gender': 2, 'id': 18876, 'job': 'Characters', 'name': 'Larry Lieber', 'profile_path': '/6zFjMrk50yZri9KiVqli477gWYB.jpg'}, {'credit_id': '52fe4311c3a36847f8037ebb', 'department': 'Writing', 'gender': 0, 'id': 18877, 'job': 'Characters', 'name': 'Don Heck', 'profile_path': None}, {'credit_id': '52fe4311c3a36847f8037f27', 'department': 'Production', 'gender': 1, 'id': 20540, 'job': 'Casting', 'name': 'Randi Hiller', 'profile_path': None}, {'credit_id': '52fe4311c3a36847f8037eef', 'department': 'Sound', 'gender': 2, 'id': 10851, 'job': 'Original Music Composer', 'name': 'Ramin Djawadi', 'profile_path': '/wgUxW19nyPnrzj4ViVOpAfmhCdr.jpg'}, {'credit_id': '59a470aec3a3680b12002c31', 'department': 'Production', 'gender': 0, 'id': 113674, 'job': 'Co-Producer', 'name': 'Victoria Alonso', 'profile_path': '/xF7Qe1tqgk9KtY8kThKHBWhMqxc.jpg'}, {'credit_id': '52fe4311c3a36847f8037f1b', 'department': 'Production', 'gender': 0, 'id': 937174, 'job': 'Executive Producer', 'name': 'Ari Arad', 'profile_path': None}, {'credit_id': '52fe4311c3a36847f8037f2d', 'department': 'Costume & Make-Up', 'gender': 1, 'id': 962467, 'job': 'Costume Design', 'name': 'Rebecca Bentjen', 'profile_path': None}, {'credit_id': '583b68b392514124900006c2', 'department': 'Directing', 'gender': 1, 'id': 1397300, 'job': 'Script Supervisor', 'name': 'Cristina Weigmann', 'profile_path': None}, {'credit_id': '55315822c3a3682226000621', 'department': 'Visual Effects', 'gender': 0, 'id': 1453929, 'job': 'Visual Effects', 'name': 'Andy Hass', 'profile_path': None}]",
#         "keywords": "[{'id': 539, 'name': 'middle east'}, {'id': 6163, 'name': 'arms dealer'}, {'id': 8613, 'name': 'malibu'}, {'id': 8828, 'name': 'marvel comic'}, {'id': 9715, 'name': 'superhero'}, {'id': 9717, 'name': 'based on comic'}, {'id': 12555, 'name': 'tony stark'}, {'id': 173776, 'name': 'iron man'}, {'id': 179430, 'name': 'aftercreditsstinger'}, {'id': 180547, 'name': 'marvel cinematic universe'}, {'id': 208630, 'name': 'counter terrorism'}, {'id': 209756, 'name': 'agent coulson'}]",
#         "est_rating": 4.761372112107151
#     }
# ]
